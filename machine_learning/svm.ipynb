# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# * Supervised Learning.
# * Both classification and Regression.
# * But classification extensively.

# %% [markdown]
# ## Importing the Libraries

# %%
from sklearn.datasets import load_iris
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Dataset

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Visualizing the data

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100: ]

plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color = 'blue')

plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'], color = 'red')

plt.scatter(df2['sepal length (cm)'], df2['sepal width (cm)'], color = 'green')

plt.show()

# %%
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'], color = 'blue')

plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'], color = 'red')

plt.scatter(df2['petal length (cm)'], df2['petal width (cm)'], color = 'green')

plt.show()

# %% [markdown]
# ## Data Preparation

# %%
X = df.drop( 'target', axis = 'columns')
y = df.target

# %% [markdown]
# ## Splitting the Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y, 
    test_size=0.3
)

# %% [markdown]
# ## Model Creation

# %%
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Model Prediction

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, 1, 0, 1, 1, 0, 2, 1, 0, 1, 1, 2, 0, 1, 2, 1, 2, 1, 2, 2,
#        1, 2, 2, 1, 0, 0, 0, 2, 0, 2, 0, 1, 1, 1, 2, 2, 0, 1, 0, 0, 1, 0,
#        0])

# %% [markdown]
# ## Model Score

# %%
print(f"Model Score: {round(model.score(X_test, y_test), 2)*100}%")
# Out:
# Model Score: 96.0%
